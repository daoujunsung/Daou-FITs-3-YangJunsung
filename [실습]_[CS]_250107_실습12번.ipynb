# %% [markdown]
# <a href="https://colab.research.google.com/github/daoujunsung/Daou-FITs-3-YangJunsung/blob/%EC%8B%A4%EC%8A%B5/%5B%EC%8B%A4%EC%8A%B5%5D_%5BCS%5D_250107_%EC%8B%A4%EC%8A%B512%EB%B2%88.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 실습과제 12 파이썬을 이용한 배열 실습

# 배열 초기화
# 정수로 이루어진 배열 초기화
arr = [1,2,3,4,5]

# 특정 값으로 초기화
arr_zeros = [0] * 5 # [0,0,0,0,0]
arr_ones = [1] * 5 # [1,1,1,1,1]

# %%
# 배열 요소 접근
arr = [10,20,30,40,50]
print(arr[0]) # 10
print(arr[2]) # 30
print(arr[-1]) # 50 (뒤에서 첫 번째 값)
# Out:
# 10
# 30
# 50

# %%
# 배열의 길이 (크기) 구하기
arr = [1,2,3,4,5]
print(len(arr)) # 5
# Out:
# 5
